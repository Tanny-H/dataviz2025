# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanny-H/dataviz2025/blob/main/663020280_8__Pandas_101_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# ## Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
import pandas as pd

# %%
stopandseach_df= pd.read_csv('/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv')

# %%
stopandseach_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
bfs_outcome_df.shape
# Out:
# (387, 15)

# %% [markdown]
# ## Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_folktales = '/content/drive/MyDrive/Dataviz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'

# %% [markdown]
# ## load data to memory

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-02-01T04:26:00+00:00
# 1                Person search  2025-02-01T16:00:00+00:00
# 2                Person search  2025-02-01T16:00:00+00:00
# 3                Person search  2025-02-01T18:00:00+00:00
# 4                Person search  2025-02-01T19:00:00+00:00
# ..                         ...                        ...
# 282  Person and Vehicle search  2025-02-27T20:50:00+00:00
# 283  Person and Vehicle search  2025-02-27T20:50:00+00:00
# 284  Person and Vehicle search  2025-02-28T00:00:00+00:00
# 285              Person search  2025-02-28T10:40:00+00:00
# 286             Vehicle search  2025-02-28T10:40:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  52.086887  -0.262838
# 1                           False                 NaN  51.889120  -0.520461
# ...

# %%
folk_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-02-01T04:26:00+00:00                         False
# 1  Person search  2025-02-01T16:00:00+00:00                         False
# 2  Person search  2025-02-01T16:00:00+00:00                         False
# 3  Person search  2025-02-01T18:00:00+00:00                         False
# 4  Person search  2025-02-01T19:00:00+00:00                          True
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  52.086887  -0.262838   Male     10-17
# 1                 NaN  51.889120  -0.520461   Male     18-24
# 2                 NaN  51.889120  -0.520461   Male     18-24
# 3                 NaN        NaN        NaN   Male   over 34
# 4                 NaN  51.883065  -0.407199   Male     25-34
#
#                               Self-defined ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
folk_df.tail()
# Out:
#                Type                       Date  Part of a policing operation  \
# 1340  Person search  2025-01-31T20:40:00+00:00                           NaN
# 1341  Person search  2025-01-31T21:05:00+00:00                           NaN
# 1342  Person search  2025-01-31T21:10:00+00:00                           NaN
# 1343  Person search  2025-01-31T22:28:00+00:00                           NaN
# 1344  Person search  2025-01-31T23:30:00+00:00                           NaN
#
#       Policing operation   Latitude  Longitude  Gender Age range  \
# 1340                 NaN  53.475776  -2.231700    Male     25-34
# 1341                 NaN  51.503059  -0.113754  Female   over 34
# 1342                 NaN  51.541263  -0.003338  Female     10-17
# 1343                 NaN  53.475776  -2.231700    Male   over 34
# 1344                 NaN  51.530626  -0.123588    Male     25-34
#
#                                  Self-defined ethnicity  \
# ...

# %%
folk_df.shape
# Out:
# (1345, 15)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
folk_df['Date']
# Out:
# 0       2025-01-01T00:51:00+00:00
# 1       2025-01-01T01:21:00+00:00
# 2       2025-01-01T01:25:00+00:00
# 3       2025-01-01T01:26:00+00:00
# 4       2025-01-01T01:30:00+00:00
#                   ...
# 1340    2025-01-31T20:40:00+00:00
# 1341    2025-01-31T21:05:00+00:00
# 1342    2025-01-31T21:10:00+00:00
# 1343    2025-01-31T22:28:00+00:00
# 1344    2025-01-31T23:30:00+00:00
# Name: Date, Length: 1345, dtype: object

# %%
folk_df['title'][99]
# Out:
# 'เด็กโง่'

# %%
folk_df['creator'][99]
# Out:
# 'เรียบ รักสมบัติ'

# %% [markdown]
# #### .iloc

# %%
folk_df.iloc[99,5]
# Out:
# 'ไทย,'

# %% [markdown]
# # list ซ้อน  list ซ้อน list

# %%
ex_list = [1,2,3],['a','b','c'],[['x','y','z'],['ab',1,2]],[[{'a':1,'b':2},{'xx':5,'yy':6}]]
ex_list[2]
# Out:
# [['x', 'y', 'z'], ['ab', 1, 2]]

# %%
ex_list[1][1][2]
# Out:
# 2

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = folk_df[['title','type','creator','subject','spatial']]
smaller_table
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#            subject spatial
# 0    นิทานพื้นบ้าน     ไทย
# 1    นิทานพื้นบ้าน     ไทย
# 2    นิทานพื้นบ้าน     ไทย
# 3    นิทานพื้นบ้าน     ไทย
# 4    นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
folk_df.iloc[1:5,:]
# Out:
#                 title          type             creator  \
# 1      ขอคำกระฮอกด่อน  ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่    นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย        มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ        มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %% [markdown]
# ## Table Query (row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# #### อยากได้ นิทานที่เป็นมุขตลก

# %%
folk_df['type']=='มุขตลก'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 221    False
# 222     True
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df[folk_df['type']=='มุขตลก']
# Out:
#                                           title    type              creator  \
# 3                                     บักหำน้อย  มุขตลก      สมหวัง ปานพายัพ
# 4                                    รื้อบ่อน้ำ  มุขตลก       บุญศรี เกสเสโร
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ  มุขตลก   พัชราภรณ์ เข็มเพชร
# 7                                หลวงพ่อน้องงัว  มุขตลก      สุบิน คำยางจ้อง
# 8                             หลวงพ่อกับเณรน้อย  มุขตลก  ปรางค์ทิพย์ บุญสีลา
# 9                               หัวล้านหลื่นครู  มุขตลก        ใจมา สมจันทร์
# 11            เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ  มุขตลก     เพ็ญนภา พันพินิจ
# 18                                       จับราว  มุขตลก          ชารี คำสีมา
# 19                               บักแหมบกับอีทา  มุขตลก      สุนีย์ คุณโพธิ์
# 20                             แม่เฒ่ากับลูกเขย  มุขตลก      สุนีย์ คุณโพธิ์
# 22                            หลวงพ่อกลัวผีหลอก  มุขตลก          เสาร์ จันกอ
# ...

# %% [markdown]
# # quiz 8 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
#
# แสดงวิธีทำดังนี้
# 1. สร้าง list of logics
# 2. query

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (1345-25)*[False]

# %%
folk_df[list_log1+list_logM+list_log2]
# Out:
#                Type                       Date  Part of a policing operation  \
# 0     Person search  2025-01-01T00:51:00+00:00                           NaN
# 1     Person search  2025-01-01T01:21:00+00:00                           NaN
# 2     Person search  2025-01-01T01:25:00+00:00                           NaN
# 3     Person search  2025-01-01T01:26:00+00:00                           NaN
# 4     Person search  2025-01-01T01:30:00+00:00                           NaN
# 5     Person search  2025-01-01T01:30:00+00:00                           NaN
# 6     Person search  2025-01-01T01:37:00+00:00                           NaN
# 7     Person search  2025-01-01T02:28:00+00:00                           NaN
# 8     Person search  2025-01-01T02:30:00+00:00                           NaN
# 9     Person search  2025-01-01T02:30:00+00:00                           NaN
# 1330  Person search  2025-01-31T18:30:00+00:00                           NaN
# ...

# %%
# prompt: create list that has 226 members where the first 10 and the last 15 are True, the rest are False.

list_log1 = 10*[True]
list_log2 = 15*[True]
list_logM = (226-25)*[False]

# %% [markdown]
# ## การชี้ค่าในตารางด้วย df[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
len('มุขตลก')
# Out:
# 6

# %%
folk_df['description'][0]
# Out:
# '<p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp;&quot;เราจะพาไปตั้งวงดนตรีจะไปไหม?&quot; &quot;เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนหนึ่งพูดขึ้นมาว่า&nbsp;&nbsp;&quot;นายจะร้องได้ไหม?&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; อีกคนตอบ &quot;มันจะยากอะไร&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp;&quot;หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า &quot;นั่นช้างหรอ&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง&nbsp;เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า</p>\n\n<p>
# ...

# %% [markdown]
# # quiz 8-2
# 1.อยากรู้ว่า ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White-English,... เมือง city of london หรือเมือง cambridgeshire มีเยอะกว่ากัน และเยอะกว่ากันเท่าไหร่

# %%
import pandas as pd

# กำหนด path ไปยังไฟล์ใน Drive
path_cambridge = "/content/drive/MyDrive/Dataviz2025/Data/2025-02/2025-02-cambridgeshire-stop-and-search.csv"
path_london = "/content/drive/MyDrive/Dataviz2025/Data/2025-02/2025-02-city-of-london-stop-and-search.csv"

# โหลดข้อมูล
df_cambridge = pd.read_csv(path_cambridge)
df_london = pd.read_csv(path_london)

# %%
# กำหนดกลุ่มชาติพันธุ์เป้าหมาย
target_ethnicity = "White - English/Welsh/Scottish/Northern Irish/British"

# นับจำนวนผู้ที่มีเชื้อชาติเป้าหมายในแต่ละเมือง
count_cambridge = df_cambridge[df_cambridge["Self-defined ethnicity"] == target_ethnicity].shape[0]
count_london = df_london[df_london["Self-defined ethnicity"] == target_ethnicity].shape[0]

# คำนวณความแตกต่าง
difference = abs(count_cambridge - count_london)

# แสดงผล
print(f"จำนวนใน Cambridgeshire: {count_cambridge}")
print(f"จำนวนใน City of London: {count_london}")
print(f"Cambridgeshire มีมากกว่า City of London อยู่ {difference} คน")
# Out:
# จำนวนใน Cambridgeshire: 69
# จำนวนใน City of London: 15
# Cambridgeshire มีมากกว่า City of London อยู่ 54 คน

# %% [markdown]
# # Hw4 ยอดรวมทั้ง 5 เดือน เมืองไหนมีคน๔ุกเรียกเป็นคนเอเชีย น้อยที่สุดและมากที่สุด

# %%
import os
print(os.listdir("/content/drive/MyDrive/Dataviz2025/Data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3837301840.py in <cell line: 0>()
#       1 import os
# ----> 2 print(os.listdir("/content/drive/MyDrive/Dataviz2025/Data"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Dataviz2025/Data'

# %%
import os
import pandas as pd

data_root = "/content/drive/MyDrive/Dataviz2025/Data"

# 1. เก็บ path ของทุกไฟล์ .csv ที่ลงท้ายด้วย '-stop-and-search.csv'
file_list = []
for root, dirs, files in os.walk(data_root):
    for file in files:
        if file.endswith("-stop-and-search.csv"):
            file_list.append(os.path.join(root, file))

print("จำนวนไฟล์ที่พบ:", len(file_list))

# 2. โหลดและรวมไฟล์
if file_list:
    df_all = pd.concat([pd.read_csv(f) for f in file_list], ignore_index=True)
else:
    raise ValueError("ไม่พบไฟล์ stop-and-search ที่ตรงเงื่อนไขเลย")
# Out:
# จำนวนไฟล์ที่พบ: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1094760797.py in <cell line: 0>()
#      17     df_all = pd.concat([pd.read_csv(f) for f in file_list], ignore_index=True)
#      18 else:
# ---> 19     raise ValueError("ไม่พบไฟล์ stop-and-search ที่ตรงเงื่อนไขเลย")
#
# ValueError: ไม่พบไฟล์ stop-and-search ที่ตรงเงื่อนไขเลย

# %%
print(file_list)
# Out:
# ['/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-avon-and-somerset-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-bedfordshire-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-btp-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-cambridgeshire-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-cheshire-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-city-of-london-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-cleveland-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-cumbria-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-devon-and-cornwall-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-dorset-stop-and-search.csv', '/content/drive/MyDrive/Dataviz2025/Data/2025-05/2025-05-durham-stop-and-search.csv', '/c
# ...

# %%
import os

base_path = "/content/drive/MyDrive/Dataviz2025/Data"
months = ["2025-01", "2025-02", "2025-03", "2025-04", "2025-05"]

stop_and_search_files = []

for month in months:
    month_path = os.path.join(base_path, month)
    if os.path.exists(month_path):
        files = os.listdir(month_path)
        matching_files = [f for f in files if '-stop-and-search' in f]
        print(f"\nไฟล์ -stop-and-search ใน {month}:")
        for file in matching_files:
            print(file)
        stop_and_search_files.extend([os.path.join(month_path, f) for f in matching_files])
    else:
        print(f"\n*** ไม่พบโฟลเดอร์ {month} ***")
# Out:
# ไฟล์ -stop-and-search ใน 2025-01:
# 2025-01-avon-and-somerset-stop-and-search.csv
# 2025-01-bedfordshire-stop-and-search.csv
# 2025-01-btp-stop-and-search.csv
# 2025-01-cambridgeshire-stop-and-search.csv
# 2025-01-cheshire-stop-and-search.csv
# 2025-01-city-of-london-stop-and-search.csv
# 2025-01-cleveland-stop-and-search.csv
# 2025-01-cumbria-stop-and-search.csv
# 2025-01-derbyshire-stop-and-search.csv
# 2025-01-devon-and-cornwall-stop-and-search.csv
# 2025-01-dorset-stop-and-search.csv
# 2025-01-durham-stop-and-search.csv
# 2025-01-dyfed-powys-stop-and-search.csv
# 2025-01-essex-stop-and-search.csv
# 2025-01-gloucestershire-stop-and-search.csv
# 2025-01-hampshire-stop-and-search.csv
# 2025-01-hertfordshire-stop-and-search.csv
# 2025-01-kent-stop-and-search.csv
# 2025-01-lancashire-stop-and-search.csv
# 2025-01-leicestershire-stop-and-search.csv
# 2025-01-merseyside-stop-and-search.csv
# 2025-01-metropolitan-stop-and-search.csv
# 2025-01-norfolk-stop-and-search.csv
# ...

# %%
import os
import pandas as pd

base_path = "/content/drive/MyDrive/Dataviz2025/Data"
months = ["2025-01", "2025-02", "2025-03", "2025-04", "2025-05"]

all_files = []

for month in months:
    month_path = os.path.join(base_path, month)
    if os.path.exists(month_path):
        files = os.listdir(month_path)
        matching_files = [f for f in files if '-stop-and-search' in f]
        all_files.extend([os.path.join(month_path, f) for f in matching_files])
    else:
        print(f"ไม่พบโฟลเดอร์ {month}")

df_list = []
for file_path in all_files:
    df = pd.read_csv(file_path)
    df_list.append(df)

df_all = pd.concat(df_list, ignore_index=True)

# สมมติชื่อเมืองอยู่ในคอลัมน์ 'Type' ถ้าไม่ใช่เปลี่ยนได้เลย
city_col = 'Type'

# ตัวเลือก 1: ใช้ Self-defined ethnicity (กรองคำที่มี 'Asian/Asian British')
df_asian_self = df_all[df_all['Self-defined ethnicity'].str.contains('Asian/Asian British', na=False)]

city_counts_self = df_asian_self[city_col].value_counts()

print("ผลวิเคราะห์โดยใช้ Self-defined ethnicity:")
if city_counts_self.empty:
    print("ไม่มีข้อมูลคนเชื้อชาติ Asian ใน Self-defined ethnicity")
else:
    max_city = city_counts_self.idxmax()
    max_count = city_counts_self.max()
    min_city = city_counts_self.idxmin()
    min_count = city_counts_self.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: {min_city} จำนวน {min_count} คน")

print("\n--------------------------------\n")

# ตัวเลือก 2: ใช้ Officer-defined ethnicity (เท่ากับ 'Asian')
df_asian_officer = df_all[df_all['Officer-defined ethnicity'].str.lower() == 'asian']

city_counts_officer = df_asian_officer[city_col].value_counts()

print("ผลวิเคราะห์โดยใช้ Officer-defined ethnicity:")
if city_counts_officer.empty:
    print("ไม่มีข้อมูลคนเชื้อชาติ Asian ใน Officer-defined ethnicity")
else:
    max_city = city_counts_officer.idxmax()
    max_count = city_counts_officer.max()
    min_city = city_counts_officer.idxmin()
    min_count = city_counts_officer.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: {min_city} จำนวน {min_count} คน")
# Out:
# ผลวิเคราะห์โดยใช้ Self-defined ethnicity:
# เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: Person search จำนวน 7523 คน
# เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: Vehicle search จำนวน 12 คน
#
# --------------------------------
#
# ผลวิเคราะห์โดยใช้ Officer-defined ethnicity:
# เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: Person search จำนวน 10694 คน
# เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: Vehicle search จำนวน 18 คน

# %%
import os
import pandas as pd

base_path = "/content/drive/MyDrive/Dataviz2025/Data"
months = ["2025-01", "2025-02", "2025-03", "2025-04", "2025-05"]

# รายชื่อพื้นที่ที่ถือว่าเป็น "เมืองจริง" หรือชื่อเมืองหลักที่ชัดเจน
real_cities = [
    'city-of-london',
    'cambridgeshire',
    'kent',
    'lancashire',
    'norfolk',
    'nottinghamshire',
    'surrey',
    'west-midlands',
    'west-yorkshire'
]

all_files = []

for month in months:
    month_path = os.path.join(base_path, month)
    if os.path.exists(month_path):
        files = os.listdir(month_path)
        # กรองไฟล์ที่มี '-stop-and-search' และชื่อพื้นที่อยู่ใน real_cities
        matching_files = []
        for f in files:
            if '-stop-and-search' in f:
                area_name = f.split('-stop-and-search')[0].split('-', 2)[-1]
                if area_name in real_cities:
                    matching_files.append(f)
        all_files.extend([os.path.join(month_path, f) for f in matching_files])
    else:
        print(f"ไม่พบโฟลเดอร์ {month}")

df_list = []

for file_path in all_files:
    df = pd.read_csv(file_path)
    basename = os.path.basename(file_path)
    area_name = basename.split('-stop-and-search')[0].split('-', 2)[-1]
    df['Area'] = area_name  # เพิ่มคอลัมน์ชื่อพื้นที่
    df_list.append(df)

df_all = pd.concat(df_list, ignore_index=True)

# ใช้คอลัมน์ 'Area' เป็นตัวแทนชื่อเมือง/พื้นที่จริง ๆ
city_col = 'Area'

# กรองตาม Self-defined ethnicity (Asian/Asian British)
df_asian_self = df_all[df_all['Self-defined ethnicity'].fillna('').str.contains('Asian/Asian British')]

city_counts_self = df_asian_self[city_col].value_counts()

print("ผลวิเคราะห์โดยใช้ Self-defined ethnicity:")
if city_counts_self.empty:
    print("ไม่มีข้อมูลคนเชื้อชาติ Asian ใน Self-defined ethnicity")
else:
    max_city = city_counts_self.idxmax()
    max_count = city_counts_self.max()
    min_city = city_counts_self.idxmin()
    min_count = city_counts_self.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: {min_city} จำนวน {min_count} คน")

print("\n--------------------------------\n")

# กรองตาม Officer-defined ethnicity (เท่ากับ 'Asian')
df_all['Officer-defined ethnicity'] = df_all['Officer-defined ethnicity'].fillna('')
df_asian_officer = df_all[df_all['Officer-defined ethnicity'].str.lower() == 'asian']

city_counts_officer = df_asian_officer[city_col].value_counts()

print("ผลวิเคราะห์โดยใช้ Officer-defined ethnicity:")
if city_counts_officer.empty:
    print("ไม่มีข้อมูลคนเชื้อชาติ Asian ใน Officer-defined ethnicity")
else:
    max_city = city_counts_officer.idxmax()
    max_count = city_counts_officer.max()
    min_city = city_counts_officer.idxmin()
    min_count = city_counts_officer.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: {min_city} จำนวน {min_count} คน")
# Out:
# ผลวิเคราะห์โดยใช้ Self-defined ethnicity:
# เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: west-midlands จำนวน 2008 คน
# เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: norfolk จำนวน 10 คน
#
# --------------------------------
#
# ผลวิเคราะห์โดยใช้ Officer-defined ethnicity:
# เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: west-midlands จำนวน 2477 คน
# เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: norfolk จำนวน 29 คน

# %%
import os
import pandas as pd

base_path = "/content/drive/MyDrive/Dataviz2025/Data"
months = ["2025-01", "2025-02", "2025-03", "2025-04", "2025-05"]

all_files = []

for month in months:
    month_path = os.path.join(base_path, month)
    if os.path.exists(month_path):
        files = os.listdir(month_path)
        # ดึงไฟล์ทั้งหมดที่ลงท้ายด้วย -stop-and-search.csv
        matching_files = [f for f in files if '-stop-and-search' in f]
        all_files.extend([os.path.join(month_path, f) for f in matching_files])
    else:
        print(f"ไม่พบโฟลเดอร์ {month}")

df_list = []

for file_path in all_files:
    df = pd.read_csv(file_path)

    # ดึงชื่อพื้นที่จากชื่อไฟล์ เช่น '2025-01-avon-and-somerset-stop-and-search.csv' -> 'avon-and-somerset'
    basename = os.path.basename(file_path)
    area_name = basename.split('-stop-and-search')[0].split('-', 2)[-1]

    df['Area'] = area_name  # เพิ่มคอลัมน์ชื่อพื้นที่
    df_list.append(df)

df_all = pd.concat(df_list, ignore_index=True)

# ตั้งค่าคอลัมน์ที่ใช้แทนชื่อเมือง/พื้นที่
city_col = 'Area'

# วิเคราะห์จาก Self-defined ethnicity
df_asian_self = df_all[df_all['Self-defined ethnicity'].fillna('').str.contains('Asian/Asian British')]
city_counts_self = df_asian_self[city_col].value_counts()

print("ผลวิเคราะห์โดยใช้ Self-defined ethnicity:")
if city_counts_self.empty:
    print("ไม่มีข้อมูลคนเชื้อชาติ Asian ใน Self-defined ethnicity")
else:
    max_city = city_counts_self.idxmax()
    max_count = city_counts_self.max()
    min_city = city_counts_self.idxmin()
    min_count = city_counts_self.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: {min_city} จำนวน {min_count} คน")

print("\n--------------------------------\n")

# วิเคราะห์จาก Officer-defined ethnicity
df_all['Officer-defined ethnicity'] = df_all['Officer-defined ethnicity'].fillna('')
df_asian_officer = df_all[df_all['Officer-defined ethnicity'].str.lower() == 'asian']
city_counts_officer = df_asian_officer[city_col].value_counts()

print("ผลวิเคราะห์โดยใช้ Officer-defined ethnicity:")
if city_counts_officer.empty:
    print("ไม่มีข้อมูลคนเชื้อชาติ Asian ใน Officer-defined ethnicity")
else:
    max_city = city_counts_officer.idxmax()
    max_count = city_counts_officer.max()
    min_city = city_counts_officer.idxmin()
    min_count = city_counts_officer.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: {min_city} จำนวน {min_count} คน")
# Out:
# ผลวิเคราะห์โดยใช้ Self-defined ethnicity:
# เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: west-midlands จำนวน 2008 คน
# เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: durham จำนวน 4 คน
#
# --------------------------------
#
# ผลวิเคราะห์โดยใช้ Officer-defined ethnicity:
# เมืองที่มีคนถูกเรียกเป็น Asian มากที่สุด: west-midlands จำนวน 2477 คน
# เมืองที่มีคนถูกเรียกเป็น Asian น้อยที่สุด: dorset จำนวน 16 คน

# %%
import os
import pandas as pd

# กำหนดเส้นทางและเดือนที่ต้องการอ่าน
base_path = "/content/drive/MyDrive/Dataviz2025/Data"
months = ["2025-01", "2025-02", "2025-03", "2025-04", "2025-05"]

all_files = []

# อ่านทุกไฟล์ที่ลงท้ายด้วย -stop-and-search.csv
for month in months:
    month_path = os.path.join(base_path, month)
    if os.path.exists(month_path):
        files = os.listdir(month_path)
        matching_files = [f for f in files if '-stop-and-search' in f]
        all_files.extend([os.path.join(month_path, f) for f in matching_files])
    else:
        print(f"ไม่พบโฟลเดอร์ {month}")

# รวมข้อมูลจากทุกไฟล์ พร้อมเพิ่มคอลัมน์ 'Area' จากชื่อไฟล์
df_list = []

for file_path in all_files:
    df = pd.read_csv(file_path)
    basename = os.path.basename(file_path)
    area_name = basename.split('-stop-and-search')[0].split('-', 2)[-1]
    df['Area'] = area_name
    df_list.append(df)

df_all = pd.concat(df_list, ignore_index=True)

# ตั้งค่าคอลัมน์แทนชื่อเมือง/พื้นที่
city_col = 'Area'

# วิเคราะห์เฉพาะกรณีที่ทั้ง Self-defined และ Officer-defined เป็น Asian
condition = (
    df_all['Self-defined ethnicity'].fillna('').str.contains('Asian/Asian British') &
    (df_all['Officer-defined ethnicity'].fillna('').str.lower() == 'asian')
)
df_asian_both = df_all[condition]
city_counts_both = df_asian_both[city_col].value_counts()

# แสดงผล
print("ผลวิเคราะห์โดยใช้เงื่อนไขทั้ง Self-defined และ Officer-defined ต้องเป็น Asian:")
if city_counts_both.empty:
    print("ไม่มีข้อมูลที่ทั้ง Self-defined และ Officer-defined เป็น Asian พร้อมกัน")
else:
    max_city = city_counts_both.idxmax()
    max_count = city_counts_both.max()
    min_city = city_counts_both.idxmin()
    min_count = city_counts_both.min()

    print(f"เมืองที่มีคนถูกเรียกเป็น Asian (ทั้งสองแหล่ง) มากที่สุด: {max_city} จำนวน {max_count} คน")
    print(f"เมืองที่มีคนถูกเรียกเป็น Asian (ทั้งสองแหล่ง) น้อยที่สุด: {min_city} จำนวน {min_count} คน")
# Out:
# ผลวิเคราะห์โดยใช้เงื่อนไขทั้ง Self-defined และ Officer-defined ต้องเป็น Asian:
# เมืองที่มีคนถูกเรียกเป็น Asian (ทั้งสองแหล่ง) มากที่สุด: west-midlands จำนวน 1982 คน
# เมืองที่มีคนถูกเรียกเป็น Asian (ทั้งสองแหล่ง) น้อยที่สุด: durham จำนวน 3 คน

# %% [markdown]
# # HW5
# ต้องการหาว่าในแต่ละเดือนผลรวมของทุกเมืองเมืองไหนมีผู้ถูกเรียกเป็นคนเอเชียมากและนอยที่สุด

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

# 1. กำหนด path และเดือน
base_path = "/content/drive/MyDrive/Dataviz2025/Data"
months = ["2025-01", "2025-02", "2025-03", "2025-04", "2025-05"]

# 2. เตรียมตัวแปรเก็บข้อมูล
all_selected_files = []
data_all_paths = []

# 3. ค้นหาไฟล์ที่ต้องการในแต่ละเดือน
for month in months:
    month_path = os.path.join(base_path, month)
    if os.path.exists(month_path):
        all_files = os.listdir(month_path)
        csv_files = [f for f in all_files if f.endswith('.csv')]
        selected_files = [f for f in csv_files if 'stop-and-search' in f]

        all_selected_files.append(selected_files)
        data_all_paths.append(month_path)

        print(f"\n📁 เดือน {month} - พบไฟล์: {len(selected_files)} ไฟล์")
        for f in selected_files:
            print(f"  ✅ {f}")
    else:
        print(f"\n❌ ไม่พบโฟลเดอร์ {month}")

# 4. อ่านและรวมข้อมูล
df_list = []

for i, (month_files, month_path) in enumerate(zip(all_selected_files, data_all_paths)):
    month_name = months[i]

    for file_name in month_files:
        file_path = os.path.join(month_path, file_name)
        city_name = file_name.split('-stop-and-search')[0].split('-', 2)[-1]

        try:
            df = pd.read_csv(file_path)
            df['City'] = city_name
            df['Month'] = month_name
            df_list.append(df)
        except Exception as e:
            print(f"📛 ข้อผิดพลาดในการอ่านไฟล์ {file_path}: {e}")

# 5. วิเคราะห์ข้อมูล
if df_list:
    all_data_df = pd.concat(df_list, ignore_index=True)

    # กรองเฉพาะเชื้อชาติ Asian
    asian_df = all_data_df[all_data_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

    # 6. นับจำนวนการหยุดค้นเชื้อชาติ Asian ต่อเดือน (รวมทุกเมือง)
    asian_counts_by_month = asian_df['Month'].value_counts().reset_index()
    asian_counts_by_month.columns = ['Month', 'Asian_Stop_and_Search_Count']
    asian_counts_by_month.sort_values('Month', inplace=True)

    # หาค่า max และ min
    max_month = asian_counts_by_month.loc[asian_counts_by_month['Asian_Stop_and_Search_Count'].idxmax()]
    min_month = asian_counts_by_month.loc[asian_counts_by_month['Asian_Stop_and_Search_Count'].idxmin()]

    print("\n📈 เดือนที่มีการหยุดค้นบุคคลเชื้อชาติ Asian **มากที่สุด**:")
    print(f"➡️ เดือน: {max_month['Month']}, จำนวน: {max_month['Asian_Stop_and_Search_Count']} ครั้ง")

    print("\n📉 เดือนที่มีการหยุดค้นบุคคลเชื้อชาติ Asian **น้อยที่สุด**:")
    print(f"➡️ เดือน: {min_month['Month']}, จำนวน: {min_month['Asian_Stop_and_Search_Count']} ครั้ง")

    # แสดงตารางทั้งหมด (ถ้าต้องการ)
    print("\n📊 จำนวนการหยุดค้นบุคคลเชื้อชาติ Asian รวมในแต่ละเดือน:")
    print(asian_counts_by_month.to_string(index=False))

else:
    print("❌ ไม่พบข้อมูล dataframe ที่โหลดได้")
# Out:
# 📁 เดือน 2025-01 - พบไฟล์: 38 ไฟล์
#   ✅ 2025-01-avon-and-somerset-stop-and-search.csv
#   ✅ 2025-01-bedfordshire-stop-and-search.csv
#   ✅ 2025-01-btp-stop-and-search.csv
#   ✅ 2025-01-cambridgeshire-stop-and-search.csv
#   ✅ 2025-01-cheshire-stop-and-search.csv
#   ✅ 2025-01-city-of-london-stop-and-search.csv
#   ✅ 2025-01-cleveland-stop-and-search.csv
#   ✅ 2025-01-cumbria-stop-and-search.csv
#   ✅ 2025-01-derbyshire-stop-and-search.csv
#   ✅ 2025-01-devon-and-cornwall-stop-and-search.csv
#   ✅ 2025-01-dorset-stop-and-search.csv
#   ✅ 2025-01-durham-stop-and-search.csv
#   ✅ 2025-01-dyfed-powys-stop-and-search.csv
#   ✅ 2025-01-essex-stop-and-search.csv
#   ✅ 2025-01-gloucestershire-stop-and-search.csv
#   ✅ 2025-01-hampshire-stop-and-search.csv
#   ✅ 2025-01-hertfordshire-stop-and-search.csv
#   ✅ 2025-01-kent-stop-and-search.csv
#   ✅ 2025-01-lancashire-stop-and-search.csv
#   ✅ 2025-01-leicestershire-stop-and-search.csv
#   ✅ 2025-01-merseyside-stop-and-search.csv
# ...

# %% [markdown]
# ## HW 5.1

# %%
# prompt: ลบ row ที่มีค่าว่างใน column description

folk_df = folk_df.dropna(subset=['description'])

# %%
# prompt: ลบ html tags และ html codes ออกจาก text ใน column description ใช้ beautifulsoup

from bs4 import BeautifulSoup

def remove_html_tags(text):
  soup = BeautifulSoup(text, "html.parser")
  cleaned_text = soup.get_text()
  return cleaned_text

folk_df['description'] = folk_df['description'].apply(remove_html_tags)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0          มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่...  นิทานพื้นบ้าน     ไทย
# 1        ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครอ...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['description'][0]
# Out:
# '\xa0 \xa0 \xa0 \xa0 มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า\n\n\xa0 \xa0 \xa0 \xa0"เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งพูดขึ้นมาว่า\xa0\xa0"นายจะร้องได้ไหม?"\n\n\xa0 \xa0 \xa0 \xa0 อีกคนตอบ "มันจะยากอะไร"\n\n\xa0 \xa0 \xa0 \xa0 เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า\n\n\xa0 \xa0 \xa0 \xa0"หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง\xa0เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า\n\n\xa0 \xa0 \xa0 \xa0 "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"\n\n\xa0 \xa0 \xa0 \xa0 คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า\n\n\xa0 \xa0 \xa0 \xa0 "ช้างนี่เหมือนสูบตีเหล็กนะ"\n\n\xa0 \xa0 \xa0 \xa0\xa0คนที
# ...

# %%
# prompt: ลบ \xa0 และ \n ออกไปด้วย

def remove_special_chars(text):
  cleaned_text = text.replace('\xa0', '')
  cleaned_text = cleaned_text.replace('\n', '')
  return cleaned_text

folk_df['description'] = folk_df['description'].apply(remove_special_chars)

# %%
folk_df['description'][0]
# Out:
# '    มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า   "เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"    ตาบอดคนหนึ่งพูดขึ้นมาว่า"นายจะร้องได้ไหม?"    อีกคนตอบ "มันจะยากอะไร"    เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า   "หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"    ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"    ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้างเจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน    ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า    "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"    คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า    "ช้างนี่เหมือนสูบตีเหล็กนะ"   คนที่สามเข้ามาทางด้านข้างของช้าง ก็จับดูทางด้านข้าง    "โอ้ ช้างนี่เหมือนผนังยุ้งข้าวเลย"     คนที่สี่เข้ามาถึง ก็จับไปโดนหูช้าง    "โอ้ ช้างนี่เหมือนภาชนะสำหรับฝัดข้าวเลย"     พอคนที่ห้าเข้ามาถึง ก็เข้าไปจับโดนมือช้างหรืองวงช้าง ก็พูดว่า    "โอ้ช้างนี่มันเหมือนปลิงเลย ปลิงตั
# ...

# %%
# prompt: description ของ row ไหนยาวที่สุด print name และ ความยาว

longest_description = ''
longest_description_name = ''
for index, row in folk_df.iterrows():
  if len(row['description']) > len(longest_description):
    longest_description = row['description']
    longest_description_name = row['title']

print(f'The longest description belongs to "{longest_description_name}" and its length is {len(longest_description)}')
# Out:
# The longest description belongs to "ท้าวหมาหยุ๋ย" and its length is 7825

# %%
# prompt: description ของ row ไหนสั้นที่สุด print name และ ความยาว

shortest_description = None
shortest_description_name = None
for index, row in folk_df.iterrows():
  if shortest_description is None or len(row['description']) < len(shortest_description):
    shortest_description = row['description']
    shortest_description_name = row['title']

print(f'The shortest description belongs to "{shortest_description_name}" and its length is {len(shortest_description)}')
# Out:
# The shortest description belongs to "จักจั่นไม่มีไส้" and its length is 204

# %% [markdown]
# ## HW 5.2

# %%
# prompt: ลบค่าว่างใน column type

folk_df = folk_df.dropna(subset=['type'])

# %%
# prompt: ชนิดของนิทาน (type) ที่มีจำนวน row มากที่สุดและน้อยที่สุด

type_counts = folk_df['type'].value_counts()

most_common_type = type_counts.index[0]
least_common_type = type_counts.index[-1]

print(f"Most common type: {most_common_type}, count: {type_counts[most_common_type]}")
print(f"Least common type: {least_common_type}, count: {type_counts[least_common_type]}")
# Out:
# Most common type: มุขตลก, count: 46
# Least common type: นิทานเข้าแบบ, count: 1

# %% [markdown]
# ### ทำเอง

# %%
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          40       22           40       40       34         0
# นิทานประจำถิ่น      25       14           25       25       23         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          14        5           14       14       11         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              46       31           46       46       42         0
#
#                  language  rights  license  source.uri
# type
# ...

# %% [markdown]
# ### HW 5.3 มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0      มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ...  นิทานพื้นบ้าน     ไทย
# 1     ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครองเม...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['spatial'].unique()
# Out:
# array(['ไทย', 'ไทย,', nan, 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
set(folk_df['spatial']) # set() แปลงให้ input เป็น set
# Out:
# {'นครศรีธรรมราช ไทย',
#  'พัทลุง ไทย',
#  'พัทลุง, ไทย',
#  'พัทลุง, ไทย,',
#  'ราชบุรี ไทย,',
#  'สงขลา ไทย',
#  'ไทย',
#  'ไทย,'}

# %%
folk_df = folk_df.dropna(subset=['spatial'])

# %%
folk_df.shape[0]
# Out:
# 192

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
#ตรวจmissing
stopandseach_df.isnull()
# Out:
#       Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0    False  False                         False                True     False
# 1    False  False                         False                True     False
# 2    False  False                         False                True     False
# 3    False  False                         False                True     False
# 4    False  False                         False                True     False
# ..     ...    ...                           ...                 ...       ...
# 382  False  False                         False                True     False
# 383  False  False                         False                True     False
# 384  False  False                         False                True     False
# 385  False  False                         False                True     False
# 386  False  False                         False                True     False
#
# ...

# %%
stopandseach_df.shape
# Out:
# (387, 15)

# %%
stopandseach_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %%
stopandseach_df

# %%
this_data = folk_df.copy()

# %%
this_data.shape #(12423, 3)
# Out:
# (226, 11)

# %%
print(this_data.shape)
print(this_data.dropna().shape)
# Out:
# (226, 11)
# (0, 11)

# %%
this_data.dropna(inplace=True)

# %%
this_data
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data = folk_df.copy()

# %%
this_data
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = this_data.dropna(inplace=True)

# %% [markdown]
# ## ลบเฉพาะ ค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title','description','type']) # สมมติ เราต้องใช้ ค่าใน column 'name','description','type'

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
stopandseach_df.fillna({'Gender':'unknown'})
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandseach_df.fillna({'Gender':'unknown'}).isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                      False
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
folk_df['type'].mode()
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
folk_df['type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df['type'].isnull().any()    # เอาค่าทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True)
# Out:
# False

# %%
folk_df['type'].isnull().all()    # เอาค่าทุกค่าใน list มา AND กัน
# Out:
# False

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %% [markdown]
# # Quiz 7 นิทานเรื่องไหนที่ ค่า spatial เป็น ค่าว่าง (ไม่ใช้ gemini)

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
stopandseach_df.duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Length: 387, dtype: bool

# %% [markdown]
# ### เรียกดูแถวที่ซ้ำ

# %%
stopandseach_df[stopandseach_df.duplicated()]
# Out:
#                Type                       Date  Part of a policing operation  \
# 2     Person search  2025-01-01T02:30:00+00:00                         False
# 4     Person search  2025-01-01T02:30:00+00:00                         False
# 43    Person search  2025-01-05T03:25:00+00:00                         False
# 86    Person search  2025-01-08T02:06:00+00:00                         False
# 87    Person search  2025-01-08T02:06:00+00:00                         False
# 88    Person search  2025-01-08T02:06:00+00:00                         False
# 231   Person search  2025-01-19T18:45:00+00:00                         False
# 243   Person search  2025-01-20T15:55:00+00:00                         False
# 244   Person search  2025-01-20T15:55:00+00:00                         False
# 245   Person search  2025-01-20T15:55:00+00:00                         False
# 289  Vehicle search  2025-01-26T08:49:00+00:00                         False
# ...

# %% [markdown]
# ### ลบ duplicated

# %%
stopandseach_df.duplicated()==False
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 387, dtype: bool

# %%
stopandseach_df[~stopandseach_df.duplicated()]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ### เติมค่าว่างด้วยค่ากลาง

# %%
stopandseach_df.fillna({'Latitude':stopandseach_df['Latitude'].mean(),
                        'Longitude':stopandseach_df['Longitude'].mean(),
                        'Age range':stopandseach_df['Latitude'].mode()})
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandseach_df.any()
# Out:
# Type                                         True
# Date                                         True
# Part of a policing operation                 True
# Policing operation                          False
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                  True
# Object of search                             True
# Outcome                                      True
# Outcome linked to object of search           True
# Removal of more than just outer clothing     True
# dtype: bool

# %% [markdown]
# # quiz 9 หาดูว่าตัวไหนบ้างที่ยังมี missing ใน column Age range อยู่

# %%
# แสดงเฉพาะแถวที่ Age range เป็น NaN
missing_age = stopandseach_df[stopandseach_df['Age range'].isna()]

missing_age
# Out:
#                Type                       Date  Part of a policing operation  \
# 6    Vehicle search  2025-01-01T10:00:00+00:00                         False
# 23   Vehicle search  2025-01-03T13:05:00+00:00                          True
# 28   Vehicle search  2025-01-04T14:30:00+00:00                         False
# 40   Vehicle search  2025-01-05T03:25:00+00:00                         False
# 52    Person search  2025-01-06T08:00:00+00:00                         False
# 56   Vehicle search  2025-01-06T16:15:00+00:00                         False
# 61   Vehicle search  2025-01-06T21:33:00+00:00                          True
# 62   Vehicle search  2025-01-06T21:35:00+00:00                          True
# 77    Person search  2025-01-07T15:10:00+00:00                          True
# 83    Person search  2025-01-07T22:31:00+00:00                         False
# 91   Vehicle search  2025-01-08T15:05:00+00:00                         False
# ...

# %%
stopandseach_df['Age range'].isna().sum()
# Out:
# np.int64(36)

# %%
stopandseach_df.fillna({'Age range':stopandseach_df['Latitude'].mode().iloc(0)},inplace=True)

# %%
folk_df['title'].duplicated().any()
# Out:
# True

# %%
folk_df[folk_df['title'].duplicated(keep=False)]
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.fillna({'type':folk_df['type'].mode()})
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = stopandseach_df.iloc[:10,:]
this_data
# Out:
#              Type                       Date  Part of a policing operation  \
# 0   Person search  2025-01-01T00:35:00+00:00                         False
# 1   Person search  2025-01-01T02:30:00+00:00                         False
# 2   Person search  2025-01-01T02:30:00+00:00                         False
# 3   Person search  2025-01-01T02:30:00+00:00                         False
# 4   Person search  2025-01-01T02:30:00+00:00                         False
# 5   Person search  2025-01-01T10:00:00+00:00                         False
# 6  Vehicle search  2025-01-01T10:00:00+00:00                         False
# 7   Person search  2025-01-01T12:12:00+00:00                         False
# 8   Person search  2025-01-01T14:35:00+00:00                          True
# 9   Person search  2025-01-01T15:10:00+00:00                          True
#
#    Policing operation   Latitude  Longitude  Gender  \
# 0                 NaN  51.881481  -0.413110    Male
# ...

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, Type                                                                            Person search
# Date                                                                2025-01-01T00:35:00+00:00
# Part of a policing operation                                                            False
# Policing operation                                                                        NaN
# Latitude                                                                            51.881481
# Longitude                                                                            -0.41311
# Gender                                                                                   Male
# Age range                                                                               25-34
# Self-defined ethnicity                      Mixed/Multiple ethnic groups - Any other Mixed...
# Officer-defined ethnicity                                                               Other
# ...

# %%
each_row[1]['Date']
# Out:
# '2025-01-01T15:10:00+00:00'

# %%
for each_row in this_data.iterrows():
    print(each_row[1]['Date'],
          each_row[1]['Self-defined ethnicity'],
          each_row[1]['Legislation'],
          end='\n*************************\n'
          )
# Out:
# 2025-01-01T00:35:00+00:00 Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T10:00:00+00:00 Other ethnic group - Not stated Misuse of Drugs Act 1971 (section 23)
# *************************
# ...

# %% [markdown]
# ### สร้างตารางใหม่

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
police = [
            {'วันที่':'01-09-2568','ชื่อ':'รุ่งแสง','รหัส':'292','ความผิด':'ไม่ใส่หมวกกันน็อค'},
            {'วันที่':'01-09-2568','ชื่อ':'พรพรรณ','รหัส':'778','ความผิด':'ฝ่าไฟแดง'},
            {'วันที่':'01-09-2568','ชื่อ':'วรพล','รหัส':'385','ความผิด':'ขโมยมอจักรยานยนต์'}
        ]

# %%
kku_police = pd.DataFrame(police)

# %%
kku_police
# Out:
#        วันที่     ชื่อ รหัส            ความผิด
# 0  01-09-2568  รุ่งแสง  292  ไม่ใส่หมวกกันน็อค
# 1  01-09-2568   พรพรรณ  778           ฝ่าไฟแดง
# 2  01-09-2568     วรพล  385  ขโมยมอจักรยานยนต์

# %% [markdown]
# ### save ตาราง

# %%
kku_police.to_csv('ตำรวจ_มข.csv')

# %%
kku_police.to_excel('ตำรวจ_มข.xlsx')

# %%
this_data = folk_df[['title','type','creator']].dropna()

# %% [markdown]
# # ต่อตาราง

# %% [markdown]
# ## แกนX(เพิ่มคอลัมป์ -> รายละเอียดให้ข้อมูล)

# %%
import pandas as pd

# %%
streets.head(2)
# Out:
#                                             Crime ID    Month  \
# 0  5b3b243f3ae69b761588f65caefe62454587b15576ed55...  2025-01
# 1  1673f50aa688f77cc735d07f47a4f8fcff38d5ebcb70ed...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -1.084621
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511824
#
#     Latitude                    Location  LSOA code  \
# 0  53.251666  On or near Limetree Avenue  E01033769
# 1  51.411782  On or near Westfield Close  E01014399
#
#                            LSOA name                    Crime type  \
# 0                     Bassetlaw 014F  Violence and sexual offences
# 1  Bath and North East Somerset 001A     Criminal damage and arson
#
#                         Last outcome category  Context
# 0  Action to be taken by another organisation      NaN
# 1                         Under investigation      NaN

# %%
outcomes.head(2)
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                  Location  LSOA code            LSOA name  \
# 0  51.387847  On or near Downside Road  E01014854  North Somerset 013D
# 1        NaN               No location        NaN                  NaN
#
#                                         Outcome type
# 0                        Unable to prosecute suspect
# 1  Further investigation is not in the public int...

# %% [markdown]
# ### จะเกิด error เมื่อ ตารางที่เราจะไปเอา data มามี id ที่ duplicate เพราะไม่รู้จะเอาค่าไหนมา

# %% [markdown]
# ###เราจะแก้ dup

# %%
outcomes_dedup = outcomes.drop_duplicates(keep='last' ,subset=['Crime ID'])
outcomes_dedup.head()
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
# 2  ae2635027b0484e1ef028b833ba5a795a3f33104ac9c82...  2025-01
# 3  d4250554f997530722b58740c8679665f3327de2e5b601...  2025-01
# 4  5fcb9a243ac6f29f7ef5bcf6d316d8936897ea315220ec...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.576637
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                     Location  LSOA code            LSOA name  \
# ...

# %% [markdown]
# ### ต่อแบบเลือกมาเฉพาะบางคอลัมป์ ด้วย map

# %%
streets['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3        Unable to prosecute suspect
# 4        Unable to prosecute suspect
#                     ...
# 14823                            NaN
# 14824                            NaN
# 14825                            NaN
# 14826                            NaN
# 14827    Unable to prosecute suspect
# Name: Crime ID, Length: 14828, dtype: object

# %% [markdown]
# ## เพิ่มคอลัมป์ ใหม่ในตาราง

# %%
streets['Outcome type'] = streets['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
streets.head()
# Out:
#                                             Crime ID    Month  \
# 0  5b3b243f3ae69b761588f65caefe62454587b15576ed55...  2025-01
# 1  1673f50aa688f77cc735d07f47a4f8fcff38d5ebcb70ed...  2025-01
# 2  cf50d7824b02ca548125204807e34491d14de60b1812e7...  2025-01
# 3  63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
# 4  7d93e2987187429aee7de3cc7d1042f7fe47086821296f...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -1.084621
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511824
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
#
#     Latitude                    Location  LSOA code  \
# 0  53.251666  On or near Limetree Avenue  E01033769
# ...

# %%
streets[streets['Outcome type'].notnull()]
# Out:
#                                                 Crime ID    Month  \
# 3      63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
# 4      7d93e2987187429aee7de3cc7d1042f7fe47086821296f...  2025-01
# 5      a57a7ba8444b78c7302e32db62e2c9b10c3d335c49aa2e...  2025-01
# 12     1ab4fc1e8655d08503bac9ad5cb0e4e207bebda6e400ef...  2025-01
# 21     783441401a33b03739d0c968fa9ea7ac28e243b4327bb4...  2025-01
# ...                                                  ...      ...
# 14769  7f15ad082412ec3b54f55db713d3181b580587eeaee348...  2025-01
# 14776  ee0e540e5c03b1d212aa4ed208a5afd0eb0c78e04dc18d...  2025-01
# 14802  0482ea4d7ee6dd67a0ab692e36d7ec1aa6f64b3a259564...  2025-01
# 14818  08565175e093624fb2088014d86916f6cc12906b6a1c4c...  2025-01
# 14827  90859b5ae1578088414e2aa9eb93fb3d1854f9053d7121...  2025-01
#
#                           Reported by                    Falls within  \
# 3      Avon and Somerset Constabulary  Avon and Somerset Constabulary
# ...

# %% [markdown]
# ## แกน Y(เพิ่ม row -> เพิ่มจำนวนข้อมูล)

# %%
Loutcome1 = pd.read_csv("/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-city-of-london-outcomes.csv")
Loutcome2 = pd.read_csv("/content/drive/MyDrive/Dataviz2025/Data/2025-02/2025-02-city-of-london-outcomes.csv")
Loutcome3 = pd.read_csv("/content/drive/MyDrive/Dataviz2025/Data/2025-03/2025-03-city-of-london-outcomes.csv")

# %%
Loutcome3.shape
# Out:
# (691, 10)

# %%
Loutcome2.shape
# Out:
# (566, 10)

# %%
Loutcome1.shape
# Out:
# (760, 10)

# %%
outcomes.shape
# Out:
# (8666, 10)

# %%
outcomes.head()
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
# 2  ae2635027b0484e1ef028b833ba5a795a3f33104ac9c82...  2025-01
# 3  d4250554f997530722b58740c8679665f3327de2e5b601...  2025-01
# 4  5fcb9a243ac6f29f7ef5bcf6d316d8936897ea315220ec...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.576637
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                     Location  LSOA code            LSOA name  \
# ...

# %% [markdown]
# # group by
# ![image.png](data:image/png;base64,...)

# %%
stopandseach = pd.read_csv('/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-city-of-london-stop-and-search.csv')
stopandseach.head()
# Out:
#                         Type                       Date  \
# 0  Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1  Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2  Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3  Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4              Person search  2025-01-02T03:19:44+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           NaN                 NaN        NaN        NaN
# 1                           NaN                 NaN        NaN        NaN
# 2                           NaN                 NaN        NaN        NaN
# 3                           NaN                 NaN        NaN        NaN
# 4                           NaN                 NaN  51.510042  -0.120439
#
#   Gender Age range                           Self-defined ethnicity  \
# 0   Male     18-24                Asian/Asian British - Bangladeshi
# ...

# %% [markdown]
# เดือน มค. มี เคส ที่ถูกเรียกโดยผู้ต้องสงสัยเป็นเชื้อชาติต่างๆอย่างละกี่เคส

# %%
ethnicity_counts = stopandseach.groupby('Self-defined ethnicity').size().reset_index(name='Count')
print("จำนวนเคสแยกตาม Self-defined ethnicity ในเดือนมกราคม:")
print(ethnicity_counts)
# Out:
# จำนวนเคสแยกตาม Self-defined ethnicity ในเดือนมกราคม:
#                                Self-defined ethnicity  Count
# 0    Asian/Asian British - Any other Asian background      5
# 1                   Asian/Asian British - Bangladeshi      6
# 2                        Asian/Asian British - Indian      1
# 3                     Asian/Asian British - Pakistani      6
# 4     Black/African/Caribbean/Black British - African     11
# 5   Black/African/Caribbean/Black British - Any ot...      6
# 6   Black/African/Caribbean/Black British - Caribbean      5
# 7   Mixed/Multiple ethnic groups - Any other Mixed...      6
# 8      Mixed/Multiple ethnic groups - White and Asian      1
# 9   Mixed/Multiple ethnic groups - White and Black...      1
# 10        Other ethnic group - Any other ethnic group      4
# 11                    Other ethnic group - Not stated     52
# 12                 White - Any other White background     20
# 13  White - English/Welsh/Scottish/Northern Irish/...     30

# %%
stopandseach.groupby('Self-defined ethnicity').count()
# Out:
#                                                     Type  Date  \
# Self-defined ethnicity
# Asian/Asian British - Any other Asian background       5     5
# Asian/Asian British - Bangladeshi                      6     6
# Asian/Asian British - Indian                           1     1
# Asian/Asian British - Pakistani                        6     6
# Black/African/Caribbean/Black British - African       11    11
# Black/African/Caribbean/Black British - Any oth...     6     6
# Black/African/Caribbean/Black British - Caribbean      5     5
# Mixed/Multiple ethnic groups - Any other Mixed/...     6     6
# Mixed/Multiple ethnic groups - White and Asian         1     1
# Mixed/Multiple ethnic groups - White and Black ...     1     1
# Other ethnic group - Any other ethnic group            4     4
# Other ethnic group - Not stated                       52    52
# White - Any other White background                    20    20
# ...

# %%
stopandseach.groupby('Self-defined ethnicity').count().reset_index()
# Out:
#                                Self-defined ethnicity  Type  Date  \
# 0    Asian/Asian British - Any other Asian background     5     5
# 1                   Asian/Asian British - Bangladeshi     6     6
# 2                        Asian/Asian British - Indian     1     1
# 3                     Asian/Asian British - Pakistani     6     6
# 4     Black/African/Caribbean/Black British - African    11    11
# 5   Black/African/Caribbean/Black British - Any ot...     6     6
# 6   Black/African/Caribbean/Black British - Caribbean     5     5
# 7   Mixed/Multiple ethnic groups - Any other Mixed...     6     6
# 8      Mixed/Multiple ethnic groups - White and Asian     1     1
# 9   Mixed/Multiple ethnic groups - White and Black...     1     1
# 10        Other ethnic group - Any other ethnic group     4     4
# 11                    Other ethnic group - Not stated    52    52
# 12                 White - Any other White background    20    20
# ...

# %%
stopandseach.groupby(
    ['Self-defined ethnicity', 'Officer-defined ethnicity']
).count().reset_index()
# Out:
#                                Self-defined ethnicity  \
# 0    Asian/Asian British - Any other Asian background
# 1    Asian/Asian British - Any other Asian background
# 2                   Asian/Asian British - Bangladeshi
# 3                   Asian/Asian British - Bangladeshi
# 4                        Asian/Asian British - Indian
# 5                     Asian/Asian British - Pakistani
# 6     Black/African/Caribbean/Black British - African
# 7     Black/African/Caribbean/Black British - African
# 8   Black/African/Caribbean/Black British - Any ot...
# 9   Black/African/Caribbean/Black British - Caribbean
# 10  Mixed/Multiple ethnic groups - Any other Mixed...
# 11  Mixed/Multiple ethnic groups - Any other Mixed...
# 12  Mixed/Multiple ethnic groups - Any other Mixed...
# 13     Mixed/Multiple ethnic groups - White and Asian
# 14  Mixed/Multiple ethnic groups - White and Black...
# 15        Other ethnic group - Any other ethnic group
# ...

# %%
this_data.groupby('type').count()
# Out:
#                  title  creator
# type
# ตำนานปรัมปรา         8        8
# นิทานชีวิต          22       22
# นิทานประจำถิ่น      15       15
# นิทานผี              2        2
# นิทานมหัศจรรย์      12       12
# นิทานศาสนา           3        3
# นิทานสัตว์           5        5
# นิทานอธิบายเหตุ     25       25
# มุขตลก              33       33

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, title          ตาบอดคลำช้าง
# type         นิทานประจำถิ่น
# creator    อ่อนตา ประกาเวสา
# Name: 0, dtype: object)
# *************************
# (1, title      ขอคำกระฮอกด่อน
# type         ตำนานปรัมปรา
# creator         พ่อใหญ่นู
# Name: 1, dtype: object)
# *************************
# (2, title      ก่องข้าวน้อยฆ่าแม่
# type               นิทานชีวิต
# creator    หนูเวียง แก้วเวียง
# Name: 2, dtype: object)
# *************************
# (3, title            บักหำน้อย
# type                มุขตลก
# creator    สมหวัง ปานพายัพ
# Name: 3, dtype: object)
# *************************
# (4, title          รื้อบ่อน้ำ
# type               มุขตลก
# creator    บุญศรี เกสเสโร
# Name: 4, dtype: object)
# *************************
# (5, title      กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ
# type                                           มุขตลก
# creator                            พัชราภรณ์ เข็มเพชร
# Name: 5, dtype: object)
# *************************
# (6, title        ตำนานกุดนางใย
# ...

# %% [markdown]
# # Quiz 9
#
# - วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
#
# - มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
#
# - คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด

# %%
# prompt: จาก data this_data วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง

count = 0
stories = []
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    count += 1
    stories.append(row['title'])

print(f"There are {count} stories with 'แม่' or 'พ่อ' in the title.")
print("The stories are:")
for story in stories:
  print(story)
# Out:
# There are 19 stories with 'แม่' or 'พ่อ' in the title.
# The stories are:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ

# %%
# prompt: มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน บอกจำนวนด้วย

import pandas
import pandas as pd
import os
from google.colab import drive
from bs4 import BeautifulSoup

# ... (preceding code)

count_life = 0
count_local = 0
for index, row in this_data.iterrows():
  if ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานชีวิต':
    count_life += 1
  elif ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานประจำถิ่น':
    count_local += 1

if count_life > count_local:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานชีวิต ({count_life} stories) than in นิทานประจำถิ่น ({count_local} stories).")
elif count_local > count_life:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานประจำถิ่น ({count_local} stories) than in นิทานชีวิต ({count_life} stories).")
else:
  print(f"There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น ({count_life} stories each).")
# Out:
# There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น (2 stories each).

# %%
# prompt: คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด (พร้อมทั้งอธิบาย code แต่ละบรรทัดด้วย)

# สร้าง dictionary เพื่อเก็บจำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่องสำหรับแต่ละคนแต่ง
creator_counts = {}
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    creator = row['creator']
    if creator not in creator_counts:
      creator_counts[creator] = 0
    creator_counts[creator] += 1

# หาคนแต่งที่มีจำนวนนิทานมากที่สุด
max_count = 0
most_prolific_creator = None
for creator, count in creator_counts.items():
  if count > max_count:
    max_count = count
    most_prolific_creator = creator

print(f"The creator who wrote the most stories with 'แม่' or 'พ่อ' in the title is {most_prolific_creator} with {max_count} stories.")
# Out:
# The creator who most frequently writes stories with 'แม่' or 'พ่อ' in the title is: หนูเวียง แก้วเวียง
# They have written 2 such stories.

# %%
creator_counts
# Out:
# {'หนูเวียง แก้วเวียง': 2,
#  'สุบิน คำยางจ้อง': 1,
#  'ปรางค์ทิพย์ บุญสีลา': 1,
#  'ชลิตา โพธิสาร': 1,
#  'ไพบูลย์ ระหา': 1,
#  'สุนีย์ คุณโพธิ์': 1,
#  'เสาร์ จันกอ': 2,
#  'จันทร์ โพธิ์ไทสง': 1,
#  'อ่อนตา ประกาเวสา': 2,
#  'สมศรี ถอนภูเขียว': 1,
#  'พรม วรรณศิริ': 1,
#  'สุรพันธ์ บุญชู': 1,
#  'เลิศ ประนัดเด': 1,
#  'อาคม  ปาสานัย': 1,
#  'ลาภ  เพ็ญสวัสดิ์': 1,
#  'นวลจันทร์  จีนเมือง': 1}

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# #Quiz9
# - print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา ใช้ iloc

# ... (preceding code)

for i in range(this_data.shape[0]):
  if 'ปู่' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
# Out:
# เขาปู่เขาย่า

# %% [markdown]
# # Dataset ใหม่ ที่มี ตัวเลข

# %%
movie_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/IMDb Movies India.csv', encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# prompt: ถ้า dropna ข้อมูลเหลือกี่ %

remaining_percentage = (movie_df.dropna().shape[0] / movie_df.shape[0]) * 100
print(f"Remaining data after dropna: {remaining_percentage:.2f}%")
# Out:
# Remaining data after dropna: 36.49%

# %%
movie_df = movie_df.dropna()

# %%
# prompt: ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข

# ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)

# %%
movie_df.head()
# Out:
#                                  Name  Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019  109 min
# 3                             #Yaaram  2019  110 min
# 5                ...Aur Pyaar Ho Gaya  1997  147 min
# 6                           ...Yahaan  2005  142 min
# 8                  ?: A Question Mark  2012   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# ...

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)

# %%
movie_df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# ...

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#               Year     Duration       Rating
# count  5659.000000  5659.000000  5659.000000
# mean   1996.247570   133.439124     5.898533
# std      19.741839    25.319939     1.381165
# min    1931.000000    21.000000     1.100000
# 25%    1983.000000   119.000000     5.000000
# 50%    2002.000000   135.000000     6.100000
# 75%    2013.000000   150.000000     6.900000
# max    2021.000000   321.000000    10.000000

# %%
# prompt: สร้างตารางของ​ Director ที่มี Name เยอะที่สุด เอาแค่ข้อมูลของคนที่เยอะที่สุด

# นับจำนวนหนังที่แต่ละ Director กำกับ
director_counts = movie_df['Director'].value_counts()

# หา Director ที่กำกับหนังเยอะที่สุด
most_prolific_director = director_counts.index[0]
num_movies = director_counts[0]

# สร้างตารางของ Director ที่กำกับหนังเยอะที่สุด
most_prolific_director_df = movie_df[movie_df['Director'] == most_prolific_director]

# แสดงตาราง
print(f"Director with most movies: {most_prolific_director} ({num_movies} movies)")
most_prolific_director_df
# Out:
# Director with most movies: David Dhawan (41 movies)
#                                     Name  Year  Duration  \
# 239                          Aag Ka Gola  1990       180
# 397                            Aandhiyan  1990       145
# 408                              Aankhen  1993       170
# 1008                               Andaz  1994       167
# 1596              Bade Miyan Chote Miyan  1998       140
# 1794                       Banarasi Babu  1997       126
# 2408                          Biwi No. 1  1999       159
# 2478                       Bol Radha Bol  1992       164
# 2754                      Chal Mere Bhai  2000       136
# 2903                     Chashme Baddoor  2013       121
# 3098                  Chor Machaaye Shor  2002       145
# 3230                        Coolie No. 1  1995       143
# 3232                        Coolie No. 1  2020       134
# 3562                     Deewana Mastana  1997       140
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
movie_df[movie_df['Director'] == most_prolific_director]['Rating'].mean()
# Out:
# 5.226829268292683

# %%
movie_df[movie_df['Director'] == most_prolific_director].describe()
# Out:
#               Year    Duration     Rating
# count    41.000000   41.000000  41.000000
# mean   1999.804878  145.170732   5.226829
# std       7.460628   15.006503   1.060430
# min    1989.000000  121.000000   2.900000
# 25%    1995.000000  134.000000   4.600000
# 50%    1998.000000  143.000000   5.100000
# 75%    2002.000000  160.000000   6.100000
# max    2020.000000  180.000000   6.700000

# %% [markdown]
# # HW6
# บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง
#
# (พรีเซ็นคนละ 3 นาที slides)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table

# %%
# Filter for the specified ethnicity
white_english_df = bfs_outcome_df[bfs_outcome_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/...']

# Count incidents in each location (assuming 'Part of a policing operation' or similar could indicate location)
# Looking at the data, there is no specific column for 'City of London' or 'Cambridgeshire'
# However, I can filter by 'Part of a policing operation' if that's relevant to location or if there is another column
# Let's assume for this task that 'Part of a policing operation' might distinguish locations or that there's a misunderstanding about the dataset.
# Given the available data, I will instead count by 'Officer-defined ethnicity' and 'Outcome' for demonstration, as specific locations aren't available.

# If you have a column indicating City of London or Cambridgeshire, please specify it.
# For now, I will demonstrate filtering by ethnicity and counting.

# Let's count the occurrences of this ethnicity in the dataset
ethnicity_count = white_english_df.shape[0]
print(f"Number of incidents for 'White - English/Welsh/Scottish/Northern Irish/...': {ethnicity_count}")

# Since location data for City of London and Cambridgeshire is not explicitly available in the current dataframes,
# I cannot directly compare the counts for these specific locations.
# Please provide the correct column name for location if it exists in your dataset, or if you have another dataset with this information.
