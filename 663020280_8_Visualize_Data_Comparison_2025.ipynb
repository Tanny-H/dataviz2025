# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanny-H/dataviz2025/blob/main/663020280_8_Visualize_Data_Comparison_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
#from datetime import datetime as dt
#from datetime import time

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %%
data = pd.read_csv(path)
data.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
# 3                     White
# 4                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 2  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 3  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 4  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#                         Outcome Outcome linked to object of search  \
# 0                        Arrest                              False
# 1  A no further action disposal                                NaN
# 2  A no further action disposal                                NaN
# 3  A no further action disposal                                NaN
# 4  A no further action disposal                                NaN
#
#    Removal of more than just outer clothing
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False

# %% [markdown]
# # Quiz 12 สร้างตารางที่แสดงความถี่ของจำนวน case ที่จับโดยตำรวจเชื้อต่างชาติต่างๆ

# %%
data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
# Out:
#   Officer-defined ethnicity  Type
# 0                     Asian    81
# 1                     Black    64
# 2                     Other     9
# 3                     White   199

# %%
compared_police_eth = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth
# Out:
#   Officer-defined ethnicity  Type
# 0                     Asian    81
# 1                     Black    64
# 2                     Other     9
# 3                     White   199

# %% [markdown]
# ## Bar chart (กราฟแท่ง) (กราฟผลไม้)

# %%
import matplotlib.pyplot as plt

plt.bar(compared_police_eth.index, compared_police_eth['Type']);

# %%
plt.bar(compared_police_eth['Officer-defined ethnicity'], compared_police_eth['Type'], color=['#fc9700','black','red','blue']);
plt.xlabel('Ethnicity')
plt.ylabel('Cases')
plt.title('Number of Cases open by  Police with different Ethnicity');

# %% [markdown]
# # Stacked barchart

# %%
data1 = '/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
data2 = '/content/drive/MyDrive/Dataviz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
data3 = '/content/drive/MyDrive/Dataviz2025/Data/2025-03/2025-03-bedfordshire-stop-and-search.csv'
data4 = '/content/drive/MyDrive/Dataviz2025/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv'

# %%
data1 = pd.read_csv(data1)
compared_police_eth_1 = data1.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
data2 = pd.read_csv(data2)
compared_police_eth_2 = data2.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
data3 = pd.read_csv(data3)
compared_police_eth_3 = data3.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
data4 = pd.read_csv(data4)
compared_police_eth_4 = data4.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
def swap_rows(tab,eth1,eth2):
  # Find the indices of 'Asian' and 'Other'
  asian_index = compared_police_eth_1[compared_police_eth_1['Officer-defined ethnicity'] == 'Asian'].index[0]
  other_index = compared_police_eth_1[compared_police_eth_1['Officer-defined ethnicity'] == 'Other'].index[0]

  #Get the rows
  asian_row = compared_police_eth_1.loc[asian_index]
  other_row = compared_police_eth_1.loc[other_index]

  #Swap the rows
  compared_police_eth_1.loc[asian_index] = other_row
  compared_police_eth_1.loc[other_index] = asian_row

  display(compared_police_eth_1)

# %%
# Group data by region and sum sales
#region_sales = data.groupby(['Region','Quarter'])['Sales'].sum()
#region_sales

# %%
# prompt: สร้าง bar chart เปรียบเทียบปริมาณ sales ทั้งหมดในแต่ละ quarter ของแต่ละ region ด้วย stacked barchart

import matplotlib.pyplot as plt
# Group data by region and quarter, then sum sales
#region_quarter_sales = data.groupby(['Region', 'Quarter'])['Sales'].sum().unstack()

# Create the stacked bar chart
#region_quarter_sales.plot(kind='bar', stacked=True)

# Add labels and title
#plt.xlabel('Region')
#plt.ylabel('Total Sales')
#plt.title('Total Sales by Region and Quarter')

# Show the plot
#plt.show()

# %% [markdown]
# ## plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
#region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
#region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
#plt.xlabel('Region')
#plt.ylabel('Total Sales')
#plt.title('Total Sales by Region and Price Category')

# Show the plot
#plt.show()

# %% [markdown]
# การแสดงตัวอักษรภาษาไทยในกราฟ matplotlib
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31
#
#
# https://colab.research.google.com/drive/1sTdTZx_Cm51mc8OL_QHtehWyO4725sGl#scrollTo=Ak9SbVd5L7U8

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(compared_police_eth_1))  # กำหนดตำแหน่งแท่ง
width = 0.25  # ความกว้างของแต่ละแท่ง

fig, ax = plt.subplots(figsize=(10,6))

# แท่งสำหรับแต่ละเดือน
rects1 = ax.bar(x - width, compared_police_eth_1['Type'], width, label='ม.ค.', color='#fc9700')
rects2 = ax.bar(x, compared_police_eth_2['Type'], width, label='ก.พ.', color='#19038a')
rects3 = ax.bar(x + width, compared_police_eth_3['Type'], width, label='มี.ค.', color='#FF5733')

# เพิ่มรายละเอียดกราฟ
ax.set_ylabel('Number of Cases')
ax.set_title('Compare number of cases between different months')
ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth_1['Officer-defined ethnicity'], rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4130294884.py in <cell line: 0>()
#       3 import matplotlib.pyplot as plt
#       4 # Group data by region and price category, then sum sales
# ----> 5 region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()
#       6
#       7 # Create the stacked bar chart
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Region'

# %% [markdown]
# ## Plot stacked barchart ด้วย matplotlib

# %%
region_brand_sales = data.groupby(['Region', 'Brand'])['Sales'].sum().unstack()
region_brand_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1599621483.py in <cell line: 0>()
# ----> 1 region_brand_sales = data.groupby(['Region', 'Brand'])['Sales'].sum().unstack()
#       2 region_brand_sales
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Region'

# %%
region_brand_sales['BrandA'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-513695926.py in <cell line: 0>()
# ----> 1 region_brand_sales['BrandA'].values
#
# NameError: name 'region_brand_sales' is not defined

# %%
region_brand_sales.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2332328229.py in <cell line: 0>()
# ----> 1 region_brand_sales.index
#
# NameError: name 'region_brand_sales' is not defined

# %% [markdown]
# ## plot ส่วนแรก

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3238841515.py in <cell line: 0>()
#       5 fig, ax = plt.subplots()
#       6
# ----> 7 ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#       8 #ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')
#       9
#
# NameError: name 'region_brand_sales' is not defined

# %% [markdown]
# ## plot ส่วนที่ 2

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width, bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3706826500.py in <cell line: 0>()
#       5 fig, ax = plt.subplots()
#       6
# ----> 7 ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#       8 ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width, bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
#       9
#
# NameError: name 'region_brand_sales' is not defined

# %% [markdown]
# ## plot ส่วนที่ 3

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width,
       bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
ax.bar(region_brand_sales.index, region_brand_sales['BrandC'].values, width,
       bottom=region_brand_sales['BrandA'].values + region_brand_sales['BrandB'].values, label='BrandC',color = '#FF5733')


ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3995570045.py in <cell line: 0>()
#       5 fig, ax = plt.subplots()
#       6
# ----> 7 ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#       8 ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width,
#       9        bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
#
# NameError: name 'region_brand_sales' is not defined

# %% [markdown]
# # Grouped bar chart (เปรียบเทียบในกลุ่ม)

# %%
# prompt: plot grouped bar chart ของแต่ละ region ในปี 2021 เพื่อเปรียบเทียบ sales ของแต่ละ price category ย้าย legend ออกไปข้างนอกกราฟ ปรับขนาด plot ให้เล็กลง 30%

import matplotlib.pyplot as plt
# Group data by region, year, and price category, then sum sales
region_year_price_category_sales = data[data['Year'] == 2021].groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the grouped bar chart
ax = region_year_price_category_sales.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category in 2021')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1073977552.py in <cell line: 0>()
#       3 import matplotlib.pyplot as plt
#       4 # Group data by region, year, and price category, then sum sales
# ----> 5 region_year_price_category_sales = data[data['Year'] == 2021].groupby(['Region', 'Price Category'])['Sales'].sum().unstack()
#       6
#       7 # Create the grouped bar chart
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Groupby chart

# %%
x = np.arange(len(compared_police_eth_1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3247221533.py in <cell line: 0>()
# ----> 1 x = np.arange(len(compared_police_eth_1))
#
# NameError: name 'compared_police_eth_1' is not defined

# %% [markdown]
# ## quiz13
# plot grouped barchart เปรียบเทียบจำนวน เคส 3 เดือน ของแต่ละเชื้อชาติ

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(compared_police_eth_1))  # กำหนดตำแหน่งแท่ง
width = 0.25  # ความกว้างของแต่ละแท่ง

fig, ax = plt.subplots(figsize=(10,6))

# แท่งสำหรับแต่ละเดือน
rects1 = ax.bar(x - width, compared_police_eth_1['Type'], width, label='Jan', color='#fc9700')
rects2 = ax.bar(x, compared_police_eth_2['Type'], width, label='Feb', color='#19038a')
rects3 = ax.bar(x + width, compared_police_eth_3['Type'], width, label='Mar', color='#FF5733')

# เพิ่มรายละเอียดกราฟ
ax.set_ylabel('Number of Cases')
ax.set_title('Compare number of cases between different months')
ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth_1['Officer-defined ethnicity'], rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## Tree map

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify
import squarify

# Group data by 'Object of search' and count the occurrences
object_counts = data['Object of search'].value_counts().reset_index()
object_counts.columns = ['Object of search', 'Count']

# Create the treemap
plt.figure(figsize=(10, 6))
squarify.plot(sizes=object_counts['Count'], label=object_counts['Object of search'], alpha=.8 )
plt.axis('off')
plt.title('Number of Cases by Object of Search')
plt.show()
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4

# %% [markdown]
# ## Plot grouped bar chart ของ หนังอินเดีย โดย แยกกลุ่มตามประเภทหนัง และเปรียบเทียบ rating จาก ความยาวของหนัง

# %%
data_india = pd.read_csv(os.path.join('/content/drive/MyDrive/Dataviz2025/Data/','IMDb Movies India.csv'), encoding='latin-1')
data_india.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-822516745.py in <cell line: 0>()
# ----> 1 data_india = pd.read_csv(os.path.join('/content/drive/MyDrive/Dataviz2025/Data/','IMDb Movies India.csv'), encoding='latin-1')
#       2 data_india.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Dataviz2025/Data/IMDb Movies India.csv'

# %%
data_india = data_india.dropna(subset=['Rating','Duration','Genre'])
data_india = data_india[['Rating','Duration','Genre']]
data_india
# Out:
#        Rating Duration                      Genre
# 1         7.0  109 min                      Drama
# 3         4.4  110 min            Comedy, Romance
# 5         4.7  147 min     Comedy, Drama, Musical
# 6         7.4  142 min        Drama, Romance, War
# 8         5.6   82 min  Horror, Mystery, Thriller
# ...       ...      ...                        ...
# 15493     6.1  115 min                      Drama
# 15494     6.2  153 min  Biography, Drama, History
# 15503     5.8  125 min       Action, Crime, Drama
# 15505     4.5  129 min              Action, Drama
# 15508     6.2  130 min              Action, Drama
#
# [5820 rows x 3 columns]

# %%
# prompt: แปลงค่าใน column duration เป็น int โดยลบ min ออกและ เปลี่ยนชนิดข้อมูลเป็น integer

# Remove " min" from the 'Duration' column and convert to integer
data_india['Duration'] = data_india['Duration'].str.replace(' min', '').astype(int)

# %%
data_india.describe()
# Out:
#             Rating     Duration
# count  5820.000000  5820.000000
# mean      5.929450   132.255155
# std       1.391797    26.557936
# min       1.100000    21.000000
# 25%       5.000000   117.000000
# 50%       6.100000   134.000000
# 75%       7.000000   150.000000
# max      10.000000   321.000000

# %%
# prompt: แยกตารางออกเป็นตารางย่อย 5 ตารางสำหรับ genre: drama, action, romance, horror, musical

# Create a dictionary to store the tables
genre_tables = {}

# Define the genres to extract
genres = ['Drama', 'Action', 'Romance', 'Horror', 'Musical']

# Iterate through the genres and create separate tables
for genre in genres:
  genre_tables[genre] = data_india[data_india['Genre'] == genre].copy()

# Access the tables using the genre as the key
# Example:
# drama_table = genre_tables['Drama']

# %%
all_table = pd.concat(genre_tables.values())
all_table
# Out:
#        Rating  Duration    Genre
# 1         7.0       109    Drama
# 10        6.2        96    Drama
# 30        7.1       116    Drama
# 32        5.6       168    Drama
# 36        4.5        94    Drama
# ...       ...       ...      ...
# 7422      5.1       127  Musical
# 7770      4.6       119  Musical
# 10989     6.7       125  Musical
# 13934     5.9       103  Musical
# 15189     5.4       132  Musical
#
# [1256 rows x 3 columns]

# %%
# prompt: แบ่ง duration ออกเป็น short, medium, long โดย short สั้นกว่า 60 medium 60-90 ที่เหลือ เป็น long

# Function to categorize duration
def categorize_duration(duration):
  if duration < 60:
    return 'short'
  elif 60 <= duration <= 90:
    return 'medium'
  else:
    return 'long'

# Apply the function to create a new column
all_table['Duration Category'] = all_table['Duration'].apply(categorize_duration)
all_table
# Out:
#        Rating  Duration    Genre Duration Category
# 1         7.0       109    Drama              long
# 10        6.2        96    Drama              long
# 30        7.1       116    Drama              long
# 32        5.6       168    Drama              long
# 36        4.5        94    Drama              long
# ...       ...       ...      ...               ...
# 7422      5.1       127  Musical              long
# 7770      4.6       119  Musical              long
# 10989     6.7       125  Musical              long
# 13934     5.9       103  Musical              long
# 15189     5.4       132  Musical              long
#
# [1256 rows x 4 columns]

# %%
all_table.groupby(['Genre','Duration Category'])['Rating'].mean()
# Out:
# Genre    Duration Category
# Action   long                 5.086228
#          medium               4.966667
#          short                4.500000
# Drama    long                 6.404376
#          medium               6.582759
#          short                6.166667
# Horror   long                 4.622222
#          medium               4.927273
#          short                4.500000
# Musical  long                 5.122222
# Romance  long                 5.523770
#          medium               5.700000
#          short                6.300000
# Name: Rating, dtype: float64

# %%
india_bar_data = all_table.groupby(['Genre','Duration Category'])['Rating'].mean().unstack()

# %%
india_bar_data
# Out:
# Duration Category      long    medium     short
# Genre
# Action             5.086228  4.966667  4.500000
# Drama              6.404376  6.582759  6.166667
# Horror             4.622222  4.927273  4.500000
# Musical            5.122222       NaN       NaN
# Romance            5.523770  5.700000  6.300000

# %%
ax = india_bar_data.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('หนังอินเดีย โดย แยกกลุ่มตามประเภทหนัง และเปรียบเทียบ rating จาก ความยาวของหนัง')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the plot
plt.show()

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
plt.title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน');

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
# Out:
# Text(0, 0.5, 'Number of Requests')

# %% [markdown]
# ## Grouped bar chart
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %% [markdown]
# แสดงปริมาณคนเข้าเว๊ปในแต่ละวัน โดยเปรียบเทียบช่วงเวลา 11:00-12:00 กับ 23:00-24:00

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)
& (data['search_timestamp'].dt.time < time(hour=12))
& (data['search_timestamp'].dt.time >= time(hour=11))].shape[0]  # monday 11:00-12:00
# Out:
# 73249

# %%
b4lunch = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0]
                         ]

# %%
b4lunch
# Out:
# [73249, 73083, 75429, 78024, 99007, 174165, 165440]

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
# Out:
# 31874

# %%
b4midnight = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
                         ]
b4midnight
# Out:
# [31874, 32258, 31153, 35944, 53174, 58306, 35801]

# %%
labels = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
import numpy as np

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, b4lunch, width, label='lunch time',color = '#fc9700')
rects2 = ax.bar(x + width/2, b4midnight, width, label='midnight',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน เปรียบเทียบ 2 ช่วงเวลา')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

# %% [markdown]
# ## Stacked bar chart

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %%
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.barh(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.barh(labels, b4midnight, width, left=b4lunch, label='before midnight',color = '#19038a')

ax.set_xlabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %% [markdown]
# ## [เช็คชื่อ] โดยให้วาด Bar chart ที่เปรียบเทียบปริมาณคนใช้งาน Wongnai.com สองช่วงเวลา โดยให้กราฟแสดงสัดส่วนของปริมาณคนใช้งานในแต่ละวันด้วย

# %% [markdown]
# ## Histogram

# %% [markdown]
# ## กราฟแสดงความถี่ของข้อมูล

# %% [markdown]
# ตัวอย่างข้อมูลที่ random มาจาก normal distribution ที่มี mean = 100  และ stdev = 15

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(2024)

mu, sigma = 100, 15
X = mu + sigma * np.random.randn(10000)

plt.hist(X, 50, facecolor = 'violet', alpha = 0.75)
# Out:
# (array([  2.,   2.,   2.,   4.,   9.,  14.,  17.,  39.,  47.,  59.,  90.,
#         144., 159., 202., 288., 325., 388., 430., 507., 537., 604., 642.,
#         650., 615., 590., 546., 534., 507., 429., 357., 323., 233., 196.,
#         171., 113.,  73.,  51.,  36.,  26.,  22.,   5.,   3.,   2.,   2.,
#           2.,   0.,   2.,   0.,   0.,   1.]),
#  array([ 44.90650513,  47.32901741,  49.7515297 ,  52.17404198,
#          54.59655427,  57.01906656,  59.44157884,  61.86409113,
#          64.28660341,  66.7091157 ,  69.13162798,  71.55414027,
#          73.97665256,  76.39916484,  78.82167713,  81.24418941,
#          83.6667017 ,  86.08921398,  88.51172627,  90.93423856,
#          93.35675084,  95.77926313,  98.20177541, 100.6242877 ,
#         103.04679998, 105.46931227, 107.89182456, 110.31433684,
#         112.73684913, 115.15936141, 117.5818737 , 120.00438598,
#         122.42689827, 124.84941056, 127.27192284, 129.69443513,
#         132.11694741, 134.5394597 , 136.96197198, 139.38448427,
#         141.80699656, 144.22950884, 146.65202113, 149.07453341,
#         151.4970457 , 153.91955798, 156.34207027, 158.76458255,
#         161.18709484, 163.60960713, 166.03211941]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ## ทดสอบกับข้อมูลหนังอินเดีย

# %%
data_india = pd.read_csv(os.path.join(path,'IMDb Movies India.csv'), encoding='latin-1')
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
len(set(data_india.dropna(subset=['Genre'])['Genre']))
# Out:
# 485

# %%
plt.hist(data_india.dropna(subset=['Genre'])['Genre'],bins = len(set(data_india.dropna(subset=['Genre'])['Genre'])))
plt.xticks(rotation='vertical');

# %%
data_india['Genre'].str.split(',', expand=True)
# Out:
#             0         1     2
# 0       Drama      None  None
# 1       Drama      None  None
# 2       Drama   Musical  None
# 3      Comedy   Romance  None
# 4       Drama      None  None
# ...       ...       ...   ...
# 15504  Action      None  None
# 15505  Action     Drama  None
# 15506  Action      None  None
# 15507  Action      None  None
# 15508  Action     Drama  None
#
# [15509 rows x 3 columns]

# %%
data_india = data_india.dropna(subset=['Genre'])

# %%
# prompt: split value in column genre by ',' and make more column for each of those

import pandas as pd
# Split the 'Genre' column by ',' and create new columns
genre_split = data_india['Genre'].str.split(',', expand=True)

# Rename the new columns
genre_split.columns = ['Genre1', 'Genre2', 'Genre3']

# Concatenate the new columns with the original DataFrame
data_india = pd.concat([data_india, genre_split], axis=1)

# Display the updated DataFrame
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3  Genre1    Genre2 Genre3
# 0  Rajendra Bhatia   Drama      None   None
# 1    Arvind Jangid   Drama      None   None
# 2       Roy Angana   Drama   Musical   None
# 3  Siddhant Kapoor  Comedy   Romance   None
# 4      Antara Mali   Drama      None   None

# %%
# prompt: delete space in the value in Genre1 Genre2 Genre3

for col in ['Genre1', 'Genre2', 'Genre3']:
  data_india[col] = data_india[col].str.strip() if data_india[col].dtype == 'object' else data_india[col]

# %%
allGenre = list(data_india['Genre1'])+list(data_india['Genre2'])+list(data_india['Genre3'])

# %%
len(set(allGenre))
# Out:
# 25

# %%
allGenre[-20:]
# Out:
# [' Romance',
#  ' Mystery',
#  ' Mystery',
#  ' Romance',
#  ' Family',
#  ' Thriller',
#  ' Thriller',
#  ' Thriller',
#  ' Mystery',
#  ' Family',
#  ' Musical',
#  ' Sci-Fi',
#  ' Family',
#  ' Family',
#  ' Thriller',
#  ' Comedy',
#  ' History',
#  ' Drama',
#  ' Drama',
#  ' Drama']

# %%
allGenre[:13]
# Out:
# ['Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Horror',
#  'Action',
#  'Drama',
#  'Horror',
#  'Horror']

# %%
# prompt: delete all None from the allGenre list

allGenre = [x for x in allGenre if x is not None]

# %%
plt.hist(allGenre,bins = len(set(allGenre)))
plt.xticks(rotation='vertical');

# %% [markdown]
# # Quiz15 หาพระเอก-นางเอก ที่มักจะแสดงคู่กัน ด้วย Histogram (พระเอก actor1, นางเอก actor2)

# %% [markdown]
# ## Tree map

# %%
# prompt: plot treemap of the genre

import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify

import squarify

# Assuming 'allGenre' contains the list of genres you want to plot
genre_counts = pd.Series(allGenre).value_counts()

# Create the treemap
squarify.plot(sizes=genre_counts.values, label=genre_counts.index, alpha=.8 )
plt.axis('off')
plt.show()
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4

# %% [markdown]
# ## Radar Chart

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data = {'client_id' : ['c1' , 'c2' , 'c3' , 'c4'],
         'cheese' : [2,5,4,3],
         'beer' : [2,1,3,5],
         'chicken' : [5,3,3,4],
        'bread' : [4,3,2,1],
       'coffee' : [2,3,5,3]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df.columns[1:])
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.iloc[:,1:].mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid' , color = '#ea3033') #เส้นกราฟ
ax.fill(angles, values, 'lightpink', alpha=0.5) #พื้นที่

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# โหลดไฟล์สองเมือง
df_cheshire = pd.read_csv("/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-cheshire-street.csv")
df_cambridge = pd.read_csv("/content/drive/MyDrive/Dataviz2025/Data/2025-01/2025-01-cambridgeshire-street.csv")

# นับจำนวนอาชญากรรมแต่ละประเภทในแต่ละเมือง
crime_cheshire = df_cheshire['Crime type'].value_counts(normalize=True) * 100
crime_cambridge = df_cambridge['Crime type'].value_counts(normalize=True) * 100

# รวม crime type ที่มีในทั้งสองเมือง
crime_total = (crime_cheshire.add(crime_cambridge, fill_value=0)).sort_values(ascending=False)

# เลือก top 5 crime type
top5_crimes = crime_total.head(5).index

# เตรียมข้อมูลสำหรับ radar chart (%)
data_cheshire = [crime_cheshire.get(c, 0) for c in top5_crimes]
data_cambridge = [crime_cambridge.get(c, 0) for c in top5_crimes]

# ปิดวงเชื่อมต่อ
data_cheshire += data_cheshire[:1]
data_cambridge += data_cambridge[:1]

# มุมสำหรับ plot
angles = np.linspace(0, 2*np.pi, len(top5_crimes), endpoint=False).tolist()
angles += angles[:1]

# --- Radar Chart ---
fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(polar=True))
ax.plot(angles, data_cheshire, linewidth=2, label="Cheshire")
ax.fill(angles, data_cheshire, alpha=0.25)

ax.plot(angles, data_cambridge, linewidth=2, label="Cambridgeshire")
ax.fill(angles, data_cambridge, alpha=0.25)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(top5_crimes, fontsize=10)
ax.set_title("Top 5 Crime Types (% Comparison)", fontsize=14)
ax.legend(loc="upper right", bbox_to_anchor=(1.3,1.1))
plt.show()

# --- ตารางสรุปเป็น % ---
summary_df = pd.DataFrame({
    "Crime Type": top5_crimes,
    "Cheshire (%)": [crime_cheshire.get(c, 0) for c in top5_crimes],
    "Cambridgeshire (%)": [crime_cambridge.get(c, 0) for c in top5_crimes]
})

print("Top 5 Crime Types (% Comparison)")
print(summary_df.round(2))
# Out:
# Top 5 Crime Types (% Comparison)
#                      Crime Type  Cheshire (%)  Cambridgeshire (%)
# 0  Violence and sexual offences         49.41               35.89
# 1         Anti-social behaviour          7.19               15.33
# 2                   Shoplifting          6.60                9.67
# 3     Criminal damage and arson          7.00                8.30
# 4                  Public order          9.72                5.30

# %% [markdown]
# # HW9 present radar chart data india
